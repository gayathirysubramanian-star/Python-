# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathirysubramanian-star/Python-/blob/main/Introduction_to_Pandas_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas
import pandas as pd

# %%
# Optional: use the pd.set_option() to display all rows in a dataframe by default
pd.set_option('display.max_rows',None)

# %% [markdown]
# # Create a DataFrame

# %%
# read the "bestsellers with categories" csv file (Dataset on Amazon's Top 50 bestselling books from 2009 to 2019.)
df = pd.read_csv('/content/bestsellers with categories.csv')

# %%
# get access to the shape attribute
df.shape
# Out:
# (550, 7)

# %%
# find the data types of each column
df.dtypes
# Out:
# Name            object
# Author          object
# User Rating    float64
# Reviews          int64
# Price            int64
# Year             int64
# Genre           object
# dtype: object

# %% [markdown]
# # Display a DataFrame

# %%
# show first 5 rows in a dataframe
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# describe basic statistics of the dataframe (mean, std, min, max)
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# # Add a new Column with an array

# %%
# Your task is to create a column named 'Critic Rating' that should have random integer numbers between 1 and 4

# 1. import numpy and create 550 random integer numbers between 1 and 4

# 2. add new 'Critic Rating' column to dataframe using the random numbers created


# Note the random numbers in this new 'Critic Rating' column will be different between your solution and mine, but we'll focus only on the code, in this section.

# %%
import numpy as np

# %%
critic_rating = np.random.randint(1,5,size = 550)
df['Critic Rating'] = critic_rating

# %%
# show first 5 rows
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre  \
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction
#
#    Critic Rating
# 0              4
# 1              2
# 2              3
# 3              2
# 4              4

# %% [markdown]
# # Basic Attributes, Methods and Functions

# %%
# get access to the columns attribute
df.columns
# Out:
# Index(['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre',
#        'Critic Rating'],
#       dtype='object')

# %% [markdown]
# # Selecting Two or More Columns from a Dataframe

# %%
pd.reset_option('display.max_rows')

# %%
# move the new 'Critic Rating' column between the columns "User Rating" and "Reviews" Then update the dataframe

# Tip: Copy and paste the column names obtained with the columns attribute and then rearrange elements using [[]]
df[['Name', 'Author', 'User Rating', 'Critic Rating', 'Reviews', 'Price', 'Year', 'Genre']]
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Critic Rating  Reviews  Price  \
# 0                    JJ Smith          4.7              4    17350      8
# 1                Stephen King          4.6              2     2052     22
# 2          Jordan B. Peterson          4.7              3    18979     15
# 3               George Orwell          4.7              2    21424      6
# 4    National Geographic Kids          4.8              4     7665     12
# ..                        ...          ...            ...      ...    ...
# 545               Jeff Kinney          4.9              1     9413      8
# 546               Jen Sincero          4.7              3    14331      8
# 547               Jen Sincero          4.7              4    14331      8
# 548               Jen Sincero          4.7              2    14331      8
# 549               Jen Sincero          4.7              4    14331      8
#
#      Year        Genre
# 0    2016  Non Fiction
# 1    2011      Fiction
# 2    2018  Non Fiction
# 3    2017      Fiction
# 4    2019  Non Fiction
# ..    ...          ...
# 545  2019      Fiction
# 546  2016  Non Fiction
# 547  2017  Non Fiction
# 548  2018  Non Fiction
# 549  2019  Non Fiction
#
# [550 rows x 8 columns]

# %% [markdown]
# # Operations on Dataframes

# %%
# create a column named "Average Rating" by using the following formula: Average Rating = (User Rating + Critic Rating)/2
average_rating = (df['User Rating'] + df['Critic Rating'])/2
df['Average Rating'] = average_rating
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic Rating  Average Rating
# 0                4            4.35
# 1                2            3.30
# 2                3            3.85
# 3                2            3.35
# 4                4            4.40
# ..             ...             ...
# 545              1            2.95
# 546              3            3.85
# 547              4            4.35
# 548              2            3.35
# 549              4            4.35
#
# [550 rows x 9 columns]

# %%
# use the round function to round the values of the dataframe to 1 decimal and update the dataframe
df = df.round(2)
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#      Critic Rating  Average Rating
# 0                4            4.35
# 1                2            3.30
# 2                3            3.85
# 3                2            3.35
# 4                4            4.40
# ..             ...             ...
# 545              1            2.95
# 546              3            3.85
# 547              4            4.35
# 548              2            3.35
# 549              4            4.35
#
# [550 rows x 9 columns]

# %% [markdown]
# # Value Counts

# %%
# count elements in "Genre" column by category and return the relative frequency
df['Genre'].value_counts(normalize = True)
# Out:
# Genre
# Non Fiction    0.563636
# Fiction        0.436364
# Name: proportion, dtype: float64

# %% [markdown]
# # Rename Columns

# %%
# rename columns "User Rating," "Critic Rating" and "Average Rating" to "UR," "CR" and "AR" then update the dataframe with the inplace paraneter
df.rename(columns = {'User Rating':'UR', 'Critic Rating':'CR', 'Average Rating':'AR'}, inplace = True)
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  Reviews  Price  Year        Genre  CR  \
# 0                    JJ Smith  4.7    17350      8  2016  Non Fiction   4
# 1                Stephen King  4.6     2052     22  2011      Fiction   2
# 2          Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   3
# 3               George Orwell  4.7    21424      6  2017      Fiction   2
# 4    National Geographic Kids  4.8     7665     12  2019  Non Fiction   4
# ..                        ...  ...      ...    ...   ...          ...  ..
# 545               Jeff Kinney  4.9     9413      8  2019      Fiction   1
# 546               Jen Sincero  4.7    14331      8  2016  Non Fiction   3
# 547               Jen Sincero  4.7    14331      8  2017  Non Fiction   4
# 548               Jen Sincero  4.7    14331      8  2018  Non Fiction   2
# 549               Jen Sincero  4.7    14331      8  2019  Non Fiction   4
#
#        AR
# 0    4.35
# 1    3.30
# 2    3.85
# 3    3.35
# 4    4.40
# ..    ...
# 545  2.95
# 546  3.85
# 547  4.35
# 548  3.35
# 549  4.35
#
# [550 rows x 9 columns]

# %%
# show first 5 rows
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author   UR  Reviews  Price  Year        Genre  CR    AR
# 0                  JJ Smith  4.7    17350      8  2016  Non Fiction   4  4.35
# 1              Stephen King  4.6     2052     22  2011      Fiction   2  3.30
# 2        Jordan B. Peterson  4.7    18979     15  2018  Non Fiction   3  3.85
# 3             George Orwell  4.7    21424      6  2017      Fiction   2  3.35
# 4  National Geographic Kids  4.8     7665     12  2019  Non Fiction   4  4.40

# %%
# select only "Name", "Author", "UR", "CR", "AR" and "Year" columns and update dataframe
df = df[["Name", "Author", "UR", "CR", "AR","Year"]]
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author   UR  CR    AR  Year
# 0                    JJ Smith  4.7   4  4.35  2016
# 1                Stephen King  4.6   2  3.30  2011
# 2          Jordan B. Peterson  4.7   3  3.85  2018
# 3               George Orwell  4.7   2  3.35  2017
# 4    National Geographic Kids  4.8   4  4.40  2019
# ..                        ...  ...  ..   ...   ...
# 545               Jeff Kinney  4.9   1  2.95  2019
# 546               Jen Sincero  4.7   3  3.85  2016
# 547               Jen Sincero  4.7   4  4.35  2017
# 548               Jen Sincero  4.7   2  3.35  2018
# 549               Jen Sincero  4.7   4  4.35  2019
#
# [550 rows x 6 columns]

# %% [markdown]
# # Sort a dataframe

# %%
# sort the dataframe descending by "UR" and "CR"
df = df.sort_values(by = ['UR','CR'],ascending = False)
df
# Out:
#                                                   Name              Author  \
# 40            Brown Bear, Brown Bear, What Do You See?     Bill Martin Jr.
# 82   Dog Man: A Tale of Two Kitties: From the Creat...          Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...          Dav Pilkey
# 151                           Hamilton: The Revolution  Lin-Manuel Miranda
# 156  Harry Potter and the Prisoner of Azkaban: The ...        J.K. Rowling
# ..                                                 ...                 ...
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...         Donna Tartt
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...           E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...           E L James
# 132                         Go Set a Watchman: A Novel          Harper Lee
# 353                                 The Casual Vacancy        J.K. Rowling
#
#       UR  CR    AR  Year
# 40   4.9   4  4.45  2017
# 82   4.9   4  4.45  2017
# 84   4.9   4  4.45  2019
# 151  4.9   4  4.45  2016
# 156  4.9   4  4.45  2017
# ..   ...  ..   ...   ...
# 392  3.9   1  2.45  2013
# 107  3.8   3  3.40  2013
# 106  3.8   1  2.40  2012
# 132  3.6   2  2.80  2015
# 353  3.3   3  3.15  2012
#
# [550 rows x 6 columns]
